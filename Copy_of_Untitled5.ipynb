# %% [markdown]
# <a href="https://colab.research.google.com/github/2205A42L02/MeghanaTelu-1/blob/main/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# given,f(x,y)=3x^2+5e^(-y)+10
#
# iteration 1 let
#
# x=2 y=3 n=0.02
#
# gradient at x=2=>d/dx(3x^2+5e^(-y)+10)
#
# =6x
#
# =6(2) =12
#
# gradient at y=>3=>d/dx(3x^2+5e^(-y)+10)
#
# =-5e^-y
#
# =-5e^-(3) =-0.248
#
# Now, Δx = -n*grad at x
#
#   = -0.02 × 12
#
#   = -0.24
#
# x1 = x +Δx
#
#   = 2+(-0.24)
#
#   x1=1.76
#
#
#
# Δy= -n*grad at y
#
#   = -0.02 × ( -5(e^(-1))
#
#   = 0.00496
#
# y1 = y +Δy
#
#   = 3 +(0.00496)
#
#   y1=3.00496
#
#   now, iteration 2
#
# x1 = 1.76
#
# y1 = 3.00496
#
# n=0.02
#
# gradient at x1=1.76 => d/dx(3x ² + 5e ^(-y) +10)
#
#                            =6x
#
#                            =6(1.76) = 10.56
#
#  gradient at Y1= 3.00496 => d/dy(3x ² + 5e ^(-y) +10)
#
#                           =-5(e^(-y))
#
#                           =-5(e^(-3.00496))
#
#                           = -0.2477036
#
#                           Now,
#
# Δx = -n*grad at x
#
#   = -0.02 × 10.56
#
#   = -0.2112
#
# x2 = x1 +Δx = 1.76+(-0.2112)
#
# x2 = 1.5488
#
# Δy= -n*grad at y
#
#   = -0.02 × (-0.2477036)
#
#   = -0.2677036
#
# y2 = y1 +Δy
#
#   =3.00496 +(-0.2477036)
#
# y2 = 2.7572564
#
# so iteration 1 :
#
# x1 = 1.76
# y1 = 3.00496
#
# and iteration 2 :
#
# x2 = 1.5488
# y2 = 2.7572564
#
# # This is formatted as code

# %%
import numpy
x_o=2
y_o=3
eta=0.02
eps=0.000001
del_x=2
del_y=3
max_iters=10000
iters=0
def deriv(x,y):
  x_deriv=6*(x)
  y_deriv=-5*(numpy.exp(-y))
  return  x_deriv,y_deriv
while max(abs(del_x),abs(del_y)) > eps and iters < max_iters:
  prev_x=x_o
  prev_y=y_o
  del_x,del_y=deriv(prev_x,prev_y) 
  del_x=-eta*del_x
  del_y=-eta*del_y
  x_o=x_o+del_x
  y_o=y_o+del_y
  iters=iters+1
  print("iteration",iters,"\n x values is",x_o,"\n y value is",y_o)
print("local minimum occurs at",x_o,y_o)
# Out:
# Streaming output truncated to the last 5000 lines.
#  y value is 6.749548328374931
# iteration 8335
#  x values is 2e-323
#  y value is 6.749665469234265
# iteration 8336
#  x values is 2e-323
#  y value is 6.749782596372422
# iteration 8337
#  x values is 2e-323
#  y value is 6.749899709792617
# iteration 8338
#  x values is 2e-323
#  y value is 6.750016809498061
# iteration 8339
#  x values is 2e-323
#  y value is 6.750133895491967
# iteration 8340
#  x values is 2e-323
#  y value is 6.7502509677775455
# iteration 8341
#  x values is 2e-323
#  y value is 6.750368026358006
# iteration 8342
#  x values is 2e-323
#  y value is 6.750485071236557
# iteration 8343
#  x values is 2e-323
#  y value is 6.750602102416407
# iteration 8344
#  x values is 2e-323
#  y value is 6.750719119900761
# iteration 8345
#  x values is 2e-323
#  y value is 6.750836123692824
# iteration 8346
#  x values is 2e-323
#  y value is 6.7509531137958
# iteration 8347
#  x values is 2e-323
# ...
